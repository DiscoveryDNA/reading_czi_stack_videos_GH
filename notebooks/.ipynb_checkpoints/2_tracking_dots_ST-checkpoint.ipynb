# %%
import numpy as np
import pandas as pd

import czifile
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np
import seaborn as sns

from IPython.display import HTML #to display movie
# %matplotlib inline

# %% [markdown]
# Tasks to work on:
# - Displaying both video together.  Displaying  two channels with two different colors?
# - Working on automating threshold
# - Work on tracking spots through time
# - to reduce noise track spot through time and only keep ones that last multiple z-stacks (possible strategy to reduce noise)
# - prepare questions for meeting with scikit image people
# Start new notebooks to tackle topics

# %% [markdown]
# # Preprocessing

# %%
# goal is to track the dots through time and reduce noise in the movie

# %%
#reading in images

array1 = czifile.imread("/Users/samanthatang/Desktop/stack_data/dmel_st14__i_63x-02.czi")
array2 = czifile.imread("/Users/samanthatang/Desktop/stack_data/dmel_st14__i_63x-03.czi")
array3 = czifile.imread("/Users/samanthatang/Desktop/stack_data/dmel_st14__i_63x-04.czi")
# array4 = czifile.imread("/Users/samanthatang/Desktop/stack_data/dmel_st14__i_63x-05.czi") #may download more later after clear up storage

# %%
## time, channel, z-stack, y-axis, and x-axis

print('Array1', np.shape(array1))
print('Array2', np.shape(array2))
print('Array3', np.shape(array3))
# print(np.shape(array4))
# Out:
# Array1 (1, 1, 6, 2, 21, 928, 1389, 1)
# Array2 (1, 1, 7, 2, 21, 928, 1389, 1)
# Array3 (1, 1, 13, 2, 21, 928, 1389, 1)

# %%
# (time, channel, z-stack, y-axis, and x-axis), 0 is the dot's channel
array1 = array1.squeeze() #get rid of unwanted channels
array1.shape
# TODO: make a function that will automatically clean up images
# Out:
# (6, 2, 21, 928, 1389)

# %%
# CODE for VISUAL: 
#going through maximum projections of all 6 time points for this image1
# fig, ax = plt.subplots(6, 2, figsize=(200, 400))
# for i in range(array1.shape[0]):
#     zstack = array1[i, 0, :, ...] #MS2 (dots)
#     IM_MAX = np.max(zstack, axis=0) #maximum projection 
    
#     ax[i, 0].imshow(IM_MAX)
#     ax[i, 1].imshow(IM_MAX[0:150, 500:700]) #need to crop better cuz dot moves out of cropped image
# #     plt.show() #what is the last max projection showing? 

#     #there's so much more noise than the previous image i looked at!


# # commented out cuz freezes computer (BUT useful for looking through images)

# %% [markdown]
# # Blob Detection

# %%
# https://scikit-image.org/docs/dev/auto_examples/features_detection/plot_blob.html#sphx-glr-auto-examples-features-detection-plot-blob-py
from skimage.feature import blob_doh, blob_dog, blob_log
from skimage.color import rgb2gray #to turn into grayscale

# %% [markdown]
# # array1 (first time point)

# %%
#preprocessing: 
zstack = array1[1, 0, :, ...] #MS2 (dots) #FIRST TIMEPOINT
IM_MAX = np.max(zstack, axis=0) #maximum projection 
image_gray = rgb2gray(IM_MAX)
image_gray
# Out:
# array([[ 7453,  7628, 10789, ...,  6989,  8890,  6306],
#        [ 6192,  9964,  7815, ...,  6735,  6735,  8884],
#        [ 8016,  6504,  7239, ...,  7568,  5915,  7384],
#        ...,
#        [ 8899,  9331,  7779, ...,  8431,  5919,  6754],
#        [ 6978,  5778,  7388, ...,  6101,  4978,  4338],
#        [ 7466,  6192,  6610, ...,  7342,  4612,  6162]], dtype=uint16)

# %%
#original image: 
plt.imshow(IM_MAX);

# %%
#using algorithms: 
#returns the coordinates of blobs and the std deviation, see documentation

#BIG EXCLAIMATION! - NOTICE that the function blob_doh is different from the variable blob'S'_doh 

blobs_doh = blob_doh(image_gray, max_sigma=30, threshold=.005) 

# blobs_dog = blob_dog(image_gray, max_sigma=30, threshold=.05) #smaller threshold captures more faint dots

# blobs_log = blob_log(image_gray, max_sigma=30, threshold=.05)

# %%
#function to display image and create dataframe: 

def show_blobs(blobs_coords): 
    
    fig, ax = plt.subplots() #created ax just to add patches
    plt.imshow(IM_MAX)

    for idx in range(len(blobs_coords)):
        for blob in blobs_coords: 
            y, x, r = blob
            c = plt.Circle((x, y), r, color="lime", linewidth=2, fill=False)
            ax.add_patch(c)


    #make into dataframe first (no cleaning)
    x = [arr[1] for arr in blobs_coords] #note, the x and y coordinates are returned in opposite order hence the indexing
    y = [arr[0] for arr in blobs_coords]
    sd = [arr[2] for arr in blobs_coords]
    timepoint_1 = pd.DataFrame({"dots": np.arange(1, len(blobs_coords)+1), "x":x, "y":y, "sd":sd})
    
    return timepoint_1

# %%
def timepoint_df(blobs_coords, tp): 
    #make into dataframe first (no cleaning)
    x = [arr[1] for arr in blobs_coords] #note, the x and y coordinates are returned in opposite order hence the indexing
    y = [arr[0] for arr in blobs_coords]
    sd = [arr[2] for arr in blobs_coords]
    timepoint = pd.DataFrame({"dots": np.arange(1, len(blobs_coords)+1), 
                              "x":x, 
                              "y":y, 
                              "sd":sd, 
                              "timept": np.zeros(len(blobs_coords)) + tp})
    
    return timepoint

# %%
show_blobs(blobs_doh)
# Out:
#    dots       x      y        sd
# 0     1   781.0  755.0  4.222222
# 1     2  1386.0  531.0  1.000000
# 2     3   677.0  365.0  4.222222
# 3     4   571.0  351.0  1.000000
# 4     5   557.0  342.0  4.222222
# 5     6  1057.0  325.0  4.222222
# 6     7   858.0  307.0  1.000000
# 7     8   768.0  143.0  7.444444
# 8     9   740.0   43.0  1.000000

# %%
blobs_dog = blob_dog(image_gray, max_sigma=30, threshold=.08) 
show(blobs_dog)
# Out:
#     dots       x      y     sd
# 0      1  1180.0  879.0  2.560
# 1      2   781.0  756.0  4.096
# 2      3   487.0  681.0  4.096
# 3      4   756.0  680.0  2.560
# 4      5  1111.0  604.0  2.560
# 5      6   831.0  564.0  2.560
# 6      7   634.0  515.0  2.560
# 7      8  1203.0  472.0  2.560
# 8      9   744.0  458.0  2.560
# 9     10   350.0  431.0  4.096
# 10    11   677.0  366.0  4.096
# 11    12   558.0  343.0  2.560
# 12    13  1058.0  326.0  2.560
# 13    14   984.0  319.0  4.096
# 14    15   491.0  243.0  2.560
# 15    16   718.0  208.0  2.560
# 16    17   769.0  145.0  4.096
# 17    18   165.0  131.0  2.560
# 18    19   348.0   56.0  4.096
# 19    20   717.0   50.0  2.560
# 20    21   845.0   46.0  2.560

# %%
plt.imshow(IM_MAX); #original image

# %% [markdown]
# **COMMENTS/NOTES**
#
# 1. I still don't know how to automate the threshold, but at least I can locate all the dots much better than before with these algorithms.
#
# Through simple analysis:
# 2. Judging from the documentation explanations and by comparing the original and blob-detected images above, I have decided to go with the blob-dog detection algorithm. The blob-doh algorithm seems to miss out on some of the more faint dots and supposedly has a harder time detecting small dots/blobs (< 3 pixels) accurately according to the documentation. As for the blob-log alogrithm, it takes too long and doesn't seem to have too much more of an advantage than the blob-dog one.
#
#
# 3. Lower threshold for blob-dog alg captures more faint dots that we may not be able to see with our eyes on the picture (since it's so small), but this can be adjusted later on.
#
#
#
# #doh: search for dog and log later for better understanding
# #https://en.wikipedia.org/wiki/Blob_detection#The_determinant_of_the_Hessian (blob detection algorithm)

# %% [markdown]
# # array1- second timepoint

# %%
#second timepoint: 

zstack2 = array1[2, 0, :, ...] #MS2 (dots) 
IM_MAX2 = np.max(zstack2, axis=0) #maximum projection 
image_gray2 = rgb2gray(IM_MAX2)
image_gray2
# Out:
# array([[9358, 8053, 8083, ..., 6129, 7047, 6971],
#        [9405, 9446, 7737, ..., 6711, 7630, 7965],
#        [7401, 7345, 8425, ..., 7492, 8340, 7012],
#        ...,
#        [6896, 7128, 8279, ..., 6853, 7228, 7724],
#        [6962, 6478, 6774, ..., 7626, 6773, 8573],
#        [7805, 7694, 9086, ..., 6523, 6106, 6753]], dtype=uint16)

# %%
plt.imshow(IM_MAX2); #ORIGINAL

# %%
blobs_dog2 = blob_dog(image_gray2, max_sigma=30, threshold=.08) 
show(blobs_dog2)
# Out:
#     dots       x      y     sd
# 0      1   171.0  839.0  2.560
# 1      2   788.0  770.0  2.560
# 2      3   577.0  769.0  2.560
# 3      4   926.0  718.0  1.600
# 4      5   431.0  701.0  2.560
# 5      6   494.0  691.0  2.560
# 6      7   764.0  687.0  2.560
# 7      8  1261.0  565.0  2.560
# 8      9   927.0  540.0  2.560
# 9     10   635.0  511.0  2.560
# 10    11   744.0  461.0  2.560
# 11    12   348.0  430.0  2.560
# 12    13   566.0  411.0  2.560
# 13    14   803.0  400.0  2.560
# 14    15   683.0  354.0  4.096
# 15    16   562.0  338.0  2.560
# 16    17  1059.0  324.0  2.560
# 17    18   982.0  324.0  4.096
# 18    19   662.0  254.0  2.560
# 19    20   773.0  129.0  2.560
# 20    21   155.0  120.0  2.560
# 21    22   340.0   61.0  2.560
# 22    23   850.0   35.0  2.560

# %% [markdown]
# # Array1 all timepoints

# %%
#get nuclei location (to generalize a coordinate area for dot locations)
#create functions to generalize process (later?, but at least do that for cleaning up array)
#want to track frequency of on and off dots (when/time)
#weka segmentation/see if it works in fiji?

# %%
def all_timepoints_combined(total_tp, array):
    
    df = pd.DataFrame() #initalize
    
    for i in range(total_tp): 
        zstack = array1[i, 0, :, ...] #MS2 (dots) 
        IM_MAX = np.max(zstack, axis=0) #maximum projection 
        image_gray = rgb2gray(IM_MAX)
        
        blobs_dog = blob_dog(image_gray, max_sigma=30, threshold=.08)
        timepoint = timepoint_df(blobs_dog, i)
        df = df.append(timepoint).reset_index(drop=True)
    
    return df

# %%
array1_timepoints = all_timepoints_combined(5, array1)

# %%
array1_timepoints.head()
# Out:
#    dots       x      y         sd  timept
# 0     1   393.0  927.0  16.777216     0.0
# 1     2  1180.0  874.0   2.560000     0.0
# 2     3   918.0  705.0   2.560000     0.0
# 3     4   486.0  670.0   2.560000     0.0
# 4     5   738.0  568.0   2.560000     0.0

# %% [markdown]
# Below is why I excluded timepoint 5 for array1:

# %%
zstack5 = array1[5, 0, :, ...] #MS2 (dots) 
IM_MAX5 = np.max(zstack5, axis=0) #maximum projection 
image_gray5 = rgb2gray(IM_MAX5)
image_gray5
# Out:
# array([[3167, 2897, 2179, ..., 2233, 4969, 4367],
#        [2496, 3651, 1843, ..., 3546, 1408, 2591],
#        [6031, 3989, 3795, ..., 2075, 2747, 2041],
#        ...,
#        [1833, 2814, 4221, ..., 1455, 1892, 2238],
#        [1291, 2490, 1938, ..., 1172,  864,  989],
#        [1738, 1020, 2018, ..., 2158, 2100, 1388]], dtype=uint16)

# %%
blobs_dog5 = blob_dog(image_gray5, max_sigma=30, threshold=.08) 
show(blobs_dog5)
# Out:
#      dots       x      y         sd
# 0       1  1189.0  927.0  26.843546
# 1       2  1042.0  927.0  16.777216
# 2       3   856.0  927.0  26.843546
# 3       4   762.0  927.0  16.777216
# 4       5   680.0  927.0  26.843546
# 5       6   610.0  927.0  10.485760
# 6       7   531.0  927.0  26.843546
# 7       8   322.0  927.0  16.777216
# 8       9   209.0  927.0  26.843546
# 9      10   427.0  899.0  16.777216
# 10     11  1343.0  896.0  16.777216
# 11     12   866.0  892.0  16.777216
# 12     13  1146.0  886.0  16.777216
# 13     14   992.0  881.0  10.485760
# 14     15   966.0  880.0  16.777216
# 15     16  1271.0  876.0  16.777216
# 16     17   114.0  874.0  16.777216
# 17     18   370.0  872.0  16.777216
# 18     19    44.0  872.0  26.843546
# 19     20   284.0  860.0  16.777216
# 20     21   610.0  856.0  16.777216
# 21     22   512.0  850.0  16.777216
# 22     23   733.0  844.0  16.777216
# 23     24  1111.0  840.0  26.843546
# 24     25  1201.0  831.0  16.777216
# ...

# %%
plt.imshow(IM_MAX5); #weird pic here, so imma ignore this timepoint for array1

# %%
array1_timepoints #can we use sd to find area of the nucleus?
# Out:
#      dots       x      y         sd  timept
# 0       1   393.0  927.0  16.777216     0.0
# 1       2  1180.0  874.0   2.560000     0.0
# 2       3   918.0  705.0   2.560000     0.0
# 3       4   486.0  670.0   2.560000     0.0
# 4       5   738.0  568.0   2.560000     0.0
# 5       6   659.0  560.0   1.600000     0.0
# 6       7  1126.0  552.0   2.560000     0.0
# 7       8  1039.0  387.0   2.560000     0.0
# 8       9   679.0  365.0   2.560000     0.0
# 9      10   568.0  353.0   2.560000     0.0
# 10     11  1053.0  329.0   2.560000     0.0
# 11     12   975.0  318.0   4.096000     0.0
# 12     13   588.0  278.0   2.560000     0.0
# 13     14   489.0  246.0   2.560000     0.0
# 14     15   385.0  222.0   2.560000     0.0
# 15     16   728.0  207.0   4.096000     0.0
# 16     17   162.0  146.0   4.096000     0.0
# 17     18   768.0  145.0   2.560000     0.0
# 18     19   340.0   66.0   2.560000     0.0
# 19     20   847.0   53.0   4.096000     0.0
# ...
